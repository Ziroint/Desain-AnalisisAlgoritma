# %% [markdown]
# Anggota Kelompok: <br>
# 1. Cia Thing (2021071029)
# 2. Muhammad Hilmi Taufiqulhakim (2021071030)
# 3. Muhammad Azi Saputra (2021071032)
# 4. Yeru Dwi Pratama Halim (2021071033)

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
data = pd.read_excel("daa.xlsx")

# %%
def load_image(name):
  img = cv2.imread(name)
  img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_cvt)
  plt.show()

# %%
print(data)
# Out:
#     No      Jenis         Nama barang      Warna
# 0    1     Outter         Jaket Denim       Biru
# 1    2     Outter         Jaket Denim      Hitam
# 2    3     Outter       Jaket Varsity      Hitam
# 3    4     Outter            Cardigan       Biru
# 4    5     Outter              Hoodie      Merah
# 5    6     Outter              Hoodie     Kuning
# 6    7     Outter             Sweater  Biru muda
# 7    8      Inner             T-shirt      Hitam
# 8    9      Inner             T-shirt      Putih
# 9   10      Inner      Kemeja Flannel      Merah
# 10  11      Inner  Kemeja Kotak-kotak      Hijau
# 11  12  Subaltern         Denim pants       Biru
# 12  13  Subaltern         Denim pants      Hitam
# 13  14  Subaltern               Joger      Hitam
# 14  15  Subaltern         Ankle Pants      Hitam
# 15  16  Subaltern               Chino      Cream

# %%
cari= input('Masukkan nama barang:')
# Out:
# Masukkan nama barang:T-shirt

# %%
i = 0
found = False
warna = []
for i in range(16):
  if data['Nama barang'][i] == cari:
    found = True
    warna.append(df['Warna'][i])

if found:
  print(f'{cari}')
else:
  print(f'{cari} tidak ditemukan!')

warna.sort()
print('Warna: {}'.format(sorted(warna)))

for w in warna:
  print("\n{} {}.png".format(cari.lower(), w.lower()))
  load_image("{} {}.png".format(cari.lower(), w.lower()))
# Out:
# T-shirt
# Warna: ['Hitam', 'Putih']
#
# t-shirt hitam.png
# t-shirt putih.png
